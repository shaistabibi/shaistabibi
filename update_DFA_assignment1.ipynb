# %% [markdown]
# **Shaista bibi**

# %% [markdown]
# **DFA 1**

# %% [markdown]
# **DFA_01 implementation**

# %% [markdown]
# ![DFA1.PNG](data:image/png;base64,...)

# %%
# Deterministic Finite Automata (DFA) implementation in python using class and objects by passing strings from dictionary
class DFA(object):
      #initialize all variable when calling the class DFA
    def __init__(self, states,input_variable , transition, initial_state,final_states):
        self.states = states;
        self.input_variable = input_variable;
        self.transition = transition;
        self.initial_state = initial_state;
        self.final_states = final_states;
        return;
    def Det_finite_Auto(self,input_string):
      states ='q0'
      for i in input_string:
        if states=='q0':
          if i=='a':
            states='q1'
          elif i=='b':
            states='q3'
          else:
            return False
        elif states=='q1':
          if i=='a':
            states='q0'
          elif i=='b':
            states='q2'
          else:
            return False
        elif states=='q2':
          if i=='a':
            states='q3'
          elif i=='b':
            states='q1'
            return False
        elif states=='q3':
           if i=='a':
             states='q2'
           elif i=='b':
             states='q0'
             return True
        else:
            return False

    #   if states in final_states:
    #     return True
    #   else:
    #     return False


dfa1 = DFA(
    input_variable=['a','b'],
    states=['q0','q1','q2','q3'],
    transition={('q0','a'):'q1',('q0','b'):'q3',('q1','a'):'q0',('q1','b'):'q2',('q2','a'):'q3',('q2','b'):'q1',('q3','a'):'q2',('q3','b'):'q0'},
    initial_state='q0',
    final_states='q0')    

if __name__ == "__main__" :
  import pandas as pd
  import numpy as np
  string={0:'abababab',
          1:'abababbb',
          2:'ababba',
          3:'bababa',
          4:'aabbab',
          5:'babbb',
          6:'aabaab'}
  for i in string:
    if(dfa1.Det_finite_Auto(string[i])):

        print(string[i],"->","is ACCEPTED")
    else:  
        print(string[i],"->"," is REJECTED")
# Out:
# abababab -> is ACCEPTED
# abababbb -> is ACCEPTED
# ababba -> is ACCEPTED
# bababa ->  is REJECTED
# aabbab -> is ACCEPTED
# babbb ->  is REJECTED
# aabaab -> is ACCEPTED

# %% [markdown]
# DFA_2 implementation

# %% [markdown]
# ![DFA2.PNG](data:image/png;base64,...)

# %%
# Deterministic Finite Automata (DFA) implementation in python using class and objects by passing strings from dictionary
class DFA_2(object):
      #initialize all variable when calling the class DFA
    def __init__(self, states,input_variable , transition, initial_state,final_states):
        self.states = states;
        self.input_variable = input_variable;
        self.transition = transition;
        self.initial_state = initial_state;
        self.final_states = final_states;
        return;
    def Det_finite_Auto(self,input_string):
      states ='q0'
      for i in input_string:
        if states=='q0':
          if i=='a':
            states='q3'
          elif i=='b':
            states='q1'
          else:
            return False
        elif states=='q1':
          if i=='a':
            states='q1'
          elif i=='b':
            states='q2'
          else:
            return False
        elif states=='q2':
          if i=='a':
            states='q2'
            return True
          elif i=='b':
            states='q2'
            return True
        elif states=='q3':
           if i=='a':
             states='q4'
           elif i=='b':
             states='q3'
             return False
        elif states=='q4':
           if i=='a':
             states='q4'
             return True
           elif i=='b':
             states='q4'
             return True
        else:
            return False

    #   if states in final_states:
    #     return True
    #   else:
    #     return False


dfa1 = DFA_2(
    input_variable=['a','b'],
    states=['q0','q1','q2','q3','q4'],
    transition={('q0','a'):'q3',('q0','b'):'q1',('q1','a'):'q1',('q1','b'):'q2',('q2','a'):'q2',('q2','b'):'q2',('q3','a'):'q4',('q3','b'):'q3',('q4','a'):'q4',('q4','b'):'q4'},
    initial_state='q0',
    final_states=['q2','q4'])    

if __name__ == "__main__" :
  string={0:'ababab',
          1:'abababbb',
          2:'ababba',
          3:'bababa',
          4:'aabbab',
          5:'babbb',
          6:'aabaab'}
  for i in string:
    if(dfa1.Det_finite_Auto(string[i])):

        print(string[i],"->","is ACCEPTED")
    else:  
        print(string[i],"->"," is REJECTED")
# Out:
# ababab ->  is REJECTED
# abababbb ->  is REJECTED
# ababba ->  is REJECTED
# bababa -> is ACCEPTED
# aabbab -> is ACCEPTED
# babbb -> is ACCEPTED
# aabaab -> is ACCEPTED

# %% [markdown]
# **DFA_03 implemetation**

# %% [markdown]
# ![DFA3.PNG](data:image/png;base64,...)

# %%
# Deterministic Finite Automata (DFA) implementation in python using class and objects by passing strings from dictionary
class DFA_3(object):
      #initialize all variable when calling the class DFA
    def __init__(self, states,input_variable , transition, initial_state,final_states):
        self.states = states;
        self.input_variable = input_variable;
        self.transition = transition;
        self.initial_state = initial_state;
        self.final_states = final_states;
        return;
    def Det_finite_Auto(self,input_string):
      states ='q0'
      for i in input_string:
        if states=='q0':
          if i=='a':
            states='q2'
            return True
          elif i=='b':
            states='q2'
            return True
          elif i=='c':
            states='q1'
          else:
            return False
        elif states=='q1':
          if i=='a':
            states='q3'
          elif i=='b':
            states='q2'
            return True
          elif i=='c':
            states='q2'
            return True
          else:
            return False
        elif states=='q2':
          if i=='a':
            states='q3'
          elif i=='b':
            states='q3'
          elif i=='c':
            states='q3'  
            return False
        elif states=='q3':
           if i=='a':
             states='q3'
           elif i=='b':
             states='q3'
           elif i=='c':
             states='q3'
             return False
        else:
            return False

    #   if states in final_states:
    #     return True
    #   else:
    #     return False


dfa1 = DFA_3(
    input_variable=['a','b','c'],
    states=['q0','q1','q2','q3'],
    transition={('q0','a'):'q2',('q0','b'):'q2',('q0','c'):'q1',('q1','a'):'q3',('q1','b'):'q2',('q1','c'):'q2',('q2','a'):'q3',('q2','b'):'q3',('q2','c'):'q3',('q3','a'):'q3',('q3','b'):'q3',('q3','c'):'q3'},
    initial_state='q0',
    final_states='q2')    

if __name__ == "__main__" :
  import pandas as pd
  import numpy as np
  string={0:'abcabcc',
          1:'abaccbbb',
          2:'abaaca',
          3:'bcaba',
          4:'cabbab',
          5:'baccabb',
          6:'cabacb'}
  for i in string:
    if(dfa1.Det_finite_Auto(string[i])):

        print(string[i],"->","is ACCEPTED")
    else:  
        print(string[i],"->"," is REJECTED")
# Out:
# abcabcc -> is ACCEPTED
# abaccbbb -> is ACCEPTED
# abaaca -> is ACCEPTED
# bcaba -> is ACCEPTED
# cabbab ->  is REJECTED
# baccabb -> is ACCEPTED
# cabacb ->  is REJECTED
